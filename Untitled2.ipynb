# %% [markdown]
# <a href="https://colab.research.google.com/github/AliyaAsanova/main/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("concrete.csv")

df = df.drop(columns='Fly Ash (component 3)(kg in a m^3 mixture)')
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
# @title Cement (component 1)(kg in a m^3 mixture)

from matplotlib import pyplot as plt
df['Cement (component 1)(kg in a m^3 mixture)'].plot(kind='hist', bins=20, title='Cement (component 1)(kg in a m^3 mixture)')
plt.gca().spines[['top', 'right',]].set_visible(False)
